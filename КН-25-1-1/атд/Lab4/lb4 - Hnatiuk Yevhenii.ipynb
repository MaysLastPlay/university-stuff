# %% [markdown]
# # Лабораторна Робота №4
# ## Тема: Рекурсія. Стратегія “розділяй і володарюй”.
# ### Мета:  Засвоїти технологію реалізації рекурсивних алгоритмів засобами Python і оцінку їх складності з використанням основної теореми рекурсії.
# #### Виконав: Гнатюк Євгеній

# %% [markdown]
# # Порядок виконання роботи
# ## Завдання 1: Реалізувати процедуру обчислення факторіалу за допомогою цикла for. Оцінити асимптотичну складність алгоритму.

# %%
def FactS(n):
    factorial = 1
    for i in range(1, n + 1):
        factorial *= i
    return factorial
FactS(5)
# Out:
# 120

# %% [markdown]
# Часова складність: $O(n)$. Цикл for виконує рівно $n$ ітерацій, на кожній з яких відбувається одна базова операція множення.

# %% [markdown]
# # Завдання 2: Реалізувати на Python алгоритм сортування методом бульбашки.
# Часова складність: O(n), від n напряму залежать кількість дій які будуть в алгоритмі.

# %%
def fac(n):
    if n == 0:
        return 1
    return fac(n - 1) * n

nst = input("Введіть число n: ")
n = int(nst)

if n < 0:
    print("Факторіал визначений лише для невід'ємних чисел.")
else:
    print(f"Факторіал числа {n}: {fac(n)}")
# Out:
# Введіть число n:  5
# Факторіал числа 5: 120

# %% [markdown]
# # Завдання 3: Оцінити асимптотичну складність рекурсивного алгоритму обчислення -го числа Фібоначчі.
# Часова складність: $O(2^n)$, бо кожна функція викликає дві функції. Чим більше n, тим більше функцій.

# %%
def fibonacci(n):
    if n == 0:
        return 0
    if n in (1, 2):
        return 1
    return fibonacci(n - 1) + fibonacci(n - 2)

n_str = input("Введіть номер числа Фібоначчі (n): ")
n = int(n_str)

if n < 0:
    print("Номер числа не може бути від'ємним.")
else:
    print(f"{n}-те число Фібоначчі: {fibonacci(n)}")
# Out:
# Введіть номер числа Фібоначчі (n):  5
# 5-те число Фібоначчі: 5

# %% [markdown]
# # Завдання 4: Оцінити асимптотичну складність алгоритму сортування злиттям, використовуючи основну теорему рекурсії.

# %%
def merge(left, right):
    result = []
    i = 0 
    j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    
    return result

def mergesort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_sorted = mergesort(left_half)
    right_sorted = mergesort(right_half)

    return merge(left_sorted, right_sorted)
print("Результат merge:")
print(merge([2, 4, 5, 7], [1, 2, 3, 6])) 
a = [8, 3, 1, 5, 4, 7, 2, 6]
print("\nРезультат mergesort(a):")
print(mergesort(a))
# Out:
# Результат merge:
# [1, 2, 2, 3, 4, 5, 6, 7]
#
# Результат mergesort(a):
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# Часова складність: $O(n)$, бо кожен елемент відсортованих масивів обробляється тільки один раз під час порівняння і додавання в результат

# %% [markdown]
# # Контрольні запитання:
# 1. $\Omega$: нижня межа складності (найкращий час роботи).
# 2. $O(N^3)$.
# 3. $O(1.01^N)$ (експонента росте швидше за поліном).
# 4. $O(N^{1.3})$ (ступінь росте швидше за логарифм).
# 5. Розпаралелювання: одночасні обчислення на кількох ядрах. Підходить сортування злиттям.
# 6. Найкраще прискорення: алгоритмічне (перехід на більш ефективний алгоритм).
